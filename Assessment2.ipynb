# %%
import pandas as pd

# %%
import numpy as np

# %%
arr=np.array([10,20,30,40,50])

# %%
print(arr)
# Out:
# [10 20 30 40 50]

# %%
print("Shape of the array:", arr.shape)
# Out:
# Shape of the array: (5,)

# %%
Series=pd.Series([1,2,3,4,5])

# %%
print(Series)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
data ={"Name":["a","b","c","d","e"],
"age":[20,21,19,22,20],
"Marks":[85,90,70,92,88]}

# %%
print(data)
# Out:
# {'Name': ['a', 'b', 'c', 'd', 'e'], 'age': [20, 21, 19, 22, 20], 'Marks': [85, 90, 70, 92, 88]}

# %%
csv_df=pd.read_csv("C:/Users/arthi/OneDrive/Dokumen/titanic2.csv")

# %%
excel_df=pd.read_excel("C:/Users/arthi/Downloads/Sample - Superstore.xls")

# %%
excel_df.head()
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  US-2022-103800 2022-01-03 2022-01-07  Standard Class    DP-13000
# 1       2  US-2022-112326 2022-01-04 2022-01-08  Standard Class    PO-19195
# 2       3  US-2022-112326 2022-01-04 2022-01-08  Standard Class    PO-19195
# 3       4  US-2022-112326 2022-01-04 2022-01-08  Standard Class    PO-19195
# 4       5  US-2022-141817 2022-01-05 2022-01-12  Standard Class    MB-18085
#
#    Customer Name      Segment Country/Region          City  ... Postal Code  \
# 0  Darren Powers     Consumer  United States       Houston  ...       77095
# 1  Phillina Ober  Home Office  United States    Naperville  ...       60540
# 2  Phillina Ober  Home Office  United States    Naperville  ...       60540
# 3  Phillina Ober  Home Office  United States    Naperville  ...       60540
# 4     Mick Brown     Consumer  United States  Philadelphia  ...       19143
#
# ...

# %%
excel_df.tail()
# Out:
#        Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 10189   10190  US-2025-143259 2025-12-30 2026-01-03  Standard Class
# 10190   10191  US-2025-115427 2025-12-30 2026-01-03  Standard Class
# 10191   10192  US-2025-156720 2025-12-30 2026-01-03  Standard Class
# 10192   10193  US-2025-143259 2025-12-30 2026-01-03  Standard Class
# 10193   10194  CA-2025-143500 2025-12-30 2026-01-03  Standard Class
#
#       Customer ID      Customer Name    Segment Country/Region           City  \
# 10189    PO-18865  Patrick O'Donnell   Consumer  United States  New York City
# 10190    EB-13975         Erica Bern  Corporate  United States      Fairfield
# 10191    JM-15580      Jill Matthias   Consumer  United States       Loveland
# 10192    PO-18865  Patrick O'Donnell   Consumer  United States  New York City
# 10193    HO-15230        Harry Olson   Consumer         Canada  Charlottetown
#
#        ... Postal Code Region       Product ID         Category Sub-Category  \
# ...

# %%
csv_df.head()
# Out:
#    Unnamed: 0  PassengerId  Survived  Sex     Age      Fare  Pclass_1  \
# 0         791          792         0    1  0.2000  0.050749         0
# 1         792          793         0    0  0.3500  0.135753         0
# 2         793          794         0    1  0.3500  0.059914         1
# 3         794          795         0    1  0.3125  0.015412         0
# 4         795          796         0    1  0.4875  0.025374         0
#
#    Pclass_2  Pclass_3  Family_size
# 0         1         0          0.0
# 1         0         1          1.0
# 2         0         0          0.0
# 3         0         1          0.0
# 4         1         0          0.0

# %%
csv_df.tail()
# Out:
#     Unnamed: 0  PassengerId  Survived  Sex     Age      Fare  Pclass_1  \
# 95         886          887         0    1  0.3375  0.025374         0
# 96         887          888         1    0  0.2375  0.058556         1
# 97         888          889         0    0  0.3500  0.045771         0
# 98         889          890         1    1  0.3250  0.058556         1
# 99         890          891         0    1  0.4000  0.015127         0
#
#     Pclass_2  Pclass_3  Family_size
# 95         1         0          0.0
# 96         0         0          0.0
# 97         0         1          0.3
# 98         0         0          0.0
# 99         0         1          0.0

# %%
print(csv_df.size)
# Out:
# 1000

# %%
print(excel_df.size)
# Out:
# 214074

# %%
print(csv_df.shape)
# Out:
# (100, 10)

# %%
print(excel_df.shape)
# Out:
# (10194, 21)

# %%
print(csv_df.columns)
# Out:
# Index(['Unnamed: 0', 'PassengerId', 'Survived', 'Sex', 'Age', 'Fare',
#        'Pclass_1', 'Pclass_2', 'Pclass_3', 'Family_size'],
#       dtype='str')

# %%
print(excel_df.columns)
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country/Region', 'City',
#        'State/Province', 'Postal Code', 'Region', 'Product ID', 'Category',
#        'Sub-Category', 'Product Name', 'Sales', 'Quantity', 'Discount',
#        'Profit'],
#       dtype='str')

# %%
print(excel_df.columns)
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country/Region', 'City',
#        'State/Province', 'Postal Code', 'Region', 'Product ID', 'Category',
#        'Sub-Category', 'Product Name', 'Sales', 'Quantity', 'Discount',
#        'Profit'],
#       dtype='str')

# %%
print(csv_df.columns)
# Out:
# Index(['Unnamed: 0', 'PassengerId', 'Survived', 'Sex', 'Age', 'Fare',
#        'Pclass_1', 'Pclass_2', 'Pclass_3', 'Family_size'],
#       dtype='str')
